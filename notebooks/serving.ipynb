# %% [markdown]
# # Pipeline de Busqueda - Cliente
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTyOB7wa_P8nM2II_U_PEYfU1VlJH8Yrb2CUQ&s)
#
# **Prerequisitos:** Ejecutar `qdrant_indexing.ipynb` primero para indexar las peliculas.

# %%
import mlflow
import dagshub
import numpy as np
import polars as pl
import requests
from IPython.display import Image, display, Markdown, HTML

from qdrant_client import QdrantClient, models
from sentence_transformers import SentenceTransformer

# Inicializar DagsHub para MLflow
dagshub.init(repo_owner='abdala9512', repo_name='dsrp-machine-learning-engineering-4', mlflow=True)
# Out:
# Initialized MLflow to track repo "abdala9512/dsrp-machine-learning-engineering-4"
# Repository abdala9512/dsrp-machine-learning-engineering-4 initialized!

# %% [markdown]
# # 0. Config

# %%
# ============= CONFIGURACION =============
import os

# Query de prueba
QUERY = "similar to 12 years a slave but more hopeful"

# Modelo LTR en MLflow
MODEL_NAME = "ltr-dsrpflix-prd-ENE12"

# Modelo de embeddings (mismo usado en feature engineering)
EMBEDDINGS_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
EMBEDDING_DIM = 384

# Qdrant - use environment variable or default to localhost
# NOTE: qdrant_client defaults to port 6333, so we must specify :80 explicitly for remote
# Set QDRANT_URL environment variable for remote:
#   export QDRANT_URL="http://qdrant-dsrp.eastus.cloudapp.azure.com:80"
# Or for port-forward:
#   kubectl port-forward svc/qdrant 6333:80
QDRANT_URL = os.getenv("QDRANT_URL", "http://qdrant-dsrp.eastus.cloudapp.azure.com:80")
COLLECTION_NAME = "imdb-movies-hybrid"

# Retrieval parameters
TOP_K_RETRIEVAL = 100  # Candidatos del retrieval
TOP_K_FINAL = 10  # Resultados finales despues del re-ranking

# Features para el modelo LTR
FEATURE_COLS = [
    "sim_embedding",
    "imdb_rating",
    "imdb_votes_log",
]

print(f"Qdrant URL: {QDRANT_URL}")
# Out:
# Qdrant URL: http://qdrant-dsrp.eastus.cloudapp.azure.com:80

# %% [markdown]
# ## 0.1 Conectar a Qdrant

# %%
# Conectar a Qdrant
client = QdrantClient(QDRANT_URL)

# Verificar que la coleccion existe
collections = [c.name for c in client.get_collections().collections]
print(f"Colecciones existentes: {collections}")

if COLLECTION_NAME not in collections:
    raise ValueError(
        f"Coleccion '{COLLECTION_NAME}' no existe. "
        f"Ejecuta primero 'qdrant_indexing.ipynb' para crear e indexar la coleccion."
    )

# Info de la coleccion
collection_info = client.get_collection(COLLECTION_NAME)
print(f"Puntos en coleccion: {collection_info.points_count}")

if collection_info.points_count == 0:
    raise ValueError(
        f"Coleccion '{COLLECTION_NAME}' esta vacia. "
        f"Ejecuta 'qdrant_indexing.ipynb' para indexar las peliculas."
    )
# Out:
# /var/folders/65/xyj4xjq9355355kxr06pqfy80000gn/T/ipykernel_70429/1810552326.py:2: UserWarning: Qdrant client version 1.16.1 is incompatible with server version 1.12.1. Major versions should match and minor version difference must not exceed 1. Set check_compatibility=False to skip version check.
#   client = QdrantClient(QDRANT_URL)
# Colecciones existentes: ['imdb-movies-hybrid']
# Puntos en coleccion: 47203

# %% [markdown]
# ## 0.2 Cargar Datos

# %%
# Cargar base de datos de peliculas
movies_db = pl.read_parquet("data/complete_imdb_database.parquet")

# Agregar features derivadas
if "imdb_votes_log" not in movies_db.columns:
    movies_db = movies_db.with_columns([
        pl.col("imdb_votes").log1p().alias("imdb_votes_log"),
    ])

# Crear texto completo para embeddings
movies_db = movies_db.with_columns([
    pl.concat_str(
        [pl.col("title"), pl.col("Plot")],
        separator=". ",
    ).fill_null("").alias("full_text"),
])

print(f"Peliculas cargadas: {movies_db.height}")
movies_db.select(["imdb_id", "title", "genres", "imdb_rating", "full_text"]).head(3)
# Out:
# Peliculas cargadas: 47203
# shape: (3, 5)
# ┌───────────┬───────────────────────┬────────────────────────┬─────────────┬───────────────────────┐
# │ imdb_id   ┆ title                 ┆ genres                 ┆ imdb_rating ┆ full_text             │
# │ ---       ┆ ---                   ┆ ---                    ┆ ---         ┆ ---                   │
# │ str       ┆ str                   ┆ str                    ┆ f64         ┆ str                   │
# ╞═══════════╪═══════════════════════╪════════════════════════╪═════════════╪═══════════════════════╡
# │ tt0002423 ┆ Passion               ┆ Biography,Drama,Romanc ┆ 6.7         ┆ Passion. The story of │
# │           ┆                       ┆ e                      ┆             ┆ Madame D…             │
# │ tt0004181 ┆ Judith of Bethulia    ┆ Drama                  ┆ 6.2         ┆ Judith of Bethulia. A │
# │           ┆                       ┆                        ┆             ┆ fascinat…             │
# ...

# %% [markdown]
# ## 0.3 Cargar Modelos

# %%
# Cargar modelo de embeddings
print("Cargando modelo de embeddings...")
embedding_model = SentenceTransformer(EMBEDDINGS_MODEL)
print("Modelo de embeddings cargado.")
# Out:
# Cargando modelo de embeddings...
# Modelo de embeddings cargado.

# %%
# ============= CARGAR MODELO LTR =============
print(f"Cargando modelo LTR: {MODEL_NAME}@champion")

try:
    ltr_model = mlflow.lightgbm.load_model(f"models:/{MODEL_NAME}@champion")
    print("Modelo LTR cargado exitosamente")
except Exception as e:
    print(f"Error cargando modelo: {e}")
    print("Intentando cargar ultima version...")
    ltr_model = mlflow.lightgbm.load_model(f"models:/{MODEL_NAME}/latest")
    print("Modelo LTR (latest) cargado")
# Out:
# Cargando modelo LTR: ltr-dsrpflix-prd-ENE12@champion
# ...
# Modelo LTR cargado exitosamente

# %% [markdown]
# # 1. Retrieval Semantico

# %%
def tokenize_text(text: str) -> dict[int, float]:
    """Tokenizar texto para sparse vectors (BM25-like)."""
    if not text:
        return {}
    
    words = text.lower().split()
    token_counts = {}
    for word in words:
        if len(word) > 2:
            idx = hash(word) % 100000
            token_counts[idx] = token_counts.get(idx, 0) + 1
    
    return token_counts

# %%
def hybrid_search(
    query: str,
    client: QdrantClient,
    collection_name: str,
    embedding_model: SentenceTransformer,
    top_k: int = 100,
    dense_weight: float = 0.7,
    sparse_weight: float = 0.3,
) -> list[dict]:
    """
    Busqueda hibrida combinando embeddings densos y BM25 sparse.
    
    Args:
        query: Texto de busqueda
        client: Cliente Qdrant
        collection_name: Nombre de la coleccion
        embedding_model: Modelo de embeddings
        top_k: Numero de resultados
        dense_weight: Peso para busqueda densa (semantica)
        sparse_weight: Peso para busqueda sparse (BM25)
    
    Returns:
        Lista de resultados con imdb_id, score y row_index
    """
    # Generar embedding de la query
    query_embedding = embedding_model.encode([query])[0].tolist()
    
    # Tokenizar query para BM25
    query_sparse = tokenize_text(query)
    
    # Busqueda hibrida usando prefetch y RRF (Reciprocal Rank Fusion)
    results = client.query_points(
        collection_name=collection_name,
        prefetch=[
            # Busqueda densa (semantica)
            models.Prefetch(
                query=query_embedding,
                using="dense",
                limit=top_k,
            ),
            # Busqueda sparse (BM25-like)
            models.Prefetch(
                query=models.SparseVector(
                    indices=list(query_sparse.keys()),
                    values=list(query_sparse.values())
                ),
                using="bm25",
                limit=top_k,
            ),
        ],
        query=models.FusionQuery(fusion=models.Fusion.RRF),  # Reciprocal Rank Fusion
        limit=top_k,
        with_payload=True,
    )
    
    # Extraer resultados
    candidates = []
    for hit in results.points:
        candidates.append({
            "imdb_id": hit.payload["imdb_id"],
            "row_index": hit.payload["row_index"],
            "retrieval_score": hit.score,
        })
    
    return candidates


def semantic_search_only(
    query: str,
    client: QdrantClient,
    collection_name: str,
    embedding_model: SentenceTransformer,
    top_k: int = 100,
) -> list[dict]:
    """Busqueda solo por embeddings densos."""
    query_embedding = embedding_model.encode([query])[0].tolist()
    
    results = client.query_points(
        collection_name=collection_name,
        query=query_embedding,
        using="dense",
        limit=top_k,
        with_payload=True,
    )
    
    candidates = []
    for hit in results.points:
        candidates.append({
            "imdb_id": hit.payload["imdb_id"],
            "row_index": hit.payload["row_index"],
            "retrieval_score": hit.score,
        })
    
    return candidates

# %%
# Test de busqueda
print(f"Query: '{QUERY}'")
print(f"\n{'='*60}")
print("BUSQUEDA HIBRIDA (Embeddings + BM25)")
print("="*60)

candidates = hybrid_search(
    query=QUERY,
    client=client,
    collection_name=COLLECTION_NAME,
    embedding_model=embedding_model,
    top_k=TOP_K_RETRIEVAL
)

print(f"Candidatos recuperados: {len(candidates)}")
print(f"\nTop 5 candidatos (pre-ranking):")
for i, c in enumerate(candidates[:5]):
    movie = movies_db.filter(pl.col("imdb_id") == c["imdb_id"])
    if not movie.is_empty():
        title = movie["title"][0]
        print(f"  {i+1}. {title} (score: {c['retrieval_score']:.4f})")
# Out:
# Query: 'similar to 12 years a slave but more hopeful'
#
# ...
# BUSQUEDA HIBRIDA (Embeddings + BM25)
# ...
# Candidatos recuperados: 100
#
# Top 5 candidatos (pre-ranking):
#   1. Always: Sunset on Third Street 2 (score: 0.5000)
#   2. 12 Years a Slave (score: 0.5000)
#   3. I Am Slave (score: 0.3333)
#   4. Bengal Tiger (score: 0.3333)
#   5. A Man and a Woman (score: 0.2500)

# %% [markdown]
# # 2. Re-Ranking modelo LTR

# %%
def rerank_candidates(
    candidates: list[dict],
    query: str,
    movies_df: pl.DataFrame,
    embedding_model: SentenceTransformer,
    ltr_model,
    feature_cols: list[str],
    top_k: int = 10,
) -> pl.DataFrame:
    """
    Re-rankear candidatos usando el modelo LTR.
    
    Args:
        candidates: Lista de candidatos del retrieval
        query: Query original
        movies_df: DataFrame con info de peliculas
        embedding_model: Modelo de embeddings
        ltr_model: Modelo LTR de MLflow
        feature_cols: Columnas de features
        top_k: Numero de resultados finales
    
    Returns:
        DataFrame con resultados rankeados
    """
    if not candidates:
        return pl.DataFrame()
    
    # Obtener IDs de candidatos
    candidate_ids = [c["imdb_id"] for c in candidates]
    retrieval_scores = {c["imdb_id"]: c["retrieval_score"] for c in candidates}
    
    # Filtrar peliculas candidatas
    candidates_df = movies_df.filter(pl.col("imdb_id").is_in(candidate_ids))
    
    if candidates_df.is_empty():
        return pl.DataFrame()
    
    # Calcular similitud de embedding query-documento
    query_emb = embedding_model.encode([query])[0]
    query_emb = query_emb / (np.linalg.norm(query_emb) + 1e-9)
    
    # Calcular embeddings de candidatos y similitud
    candidate_texts = candidates_df["full_text"].to_list()
    candidate_embs = embedding_model.encode(candidate_texts)
    candidate_embs = candidate_embs / (np.linalg.norm(candidate_embs, axis=1, keepdims=True) + 1e-9)
    
    sim_scores = candidate_embs @ query_emb
    
    # Agregar similitud al DataFrame
    candidates_df = candidates_df.with_columns([
        pl.Series("sim_embedding", sim_scores.astype("float64")),
    ])
    
    # Preparar features para el modelo
    available_cols = [c for c in feature_cols if c in candidates_df.columns]
    X = candidates_df.select(available_cols).to_numpy()
    
    # Predecir scores con modelo LTR
    ltr_scores = ltr_model.predict(X)
    
    # Agregar scores al DataFrame
    candidates_df = candidates_df.with_columns([
        pl.Series("ltr_score", ltr_scores),
        pl.Series("retrieval_score", [retrieval_scores.get(id, 0) for id in candidates_df["imdb_id"].to_list()]),
    ])
    
    # Ordenar por LTR score
    results = candidates_df.sort("ltr_score", descending=True).head(top_k)
    
    return results

# %%
# ============= RE-RANKING =============
print(f"\n{'='*60}")
print("RE-RANKING CON MODELO LTR")
print("="*60)

ranked_results = rerank_candidates(
    candidates=candidates,
    query=QUERY,
    movies_df=movies_db,
    embedding_model=embedding_model,
    ltr_model=ltr_model,
    feature_cols=FEATURE_COLS,
    top_k=TOP_K_FINAL
)

print(f"\nTop {TOP_K_FINAL} resultados despues de re-ranking:")
ranked_results.select([
    "imdb_id", "title", "genres", "imdb_rating", 
    "sim_embedding", "ltr_score"
])
# Out:
# ...
# RE-RANKING CON MODELO LTR
# ...
#
# Top 10 resultados despues de re-ranking:
# /Users/miguelarquezabdala/repos/dsrp-machine-learning-engineering-4/notebooks/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRanker was fitted with feature names
#   warnings.warn(
# shape: (10, 6)
# ┌───────────┬──────────────────────┬─────────────────────┬─────────────┬───────────────┬───────────┐
# │ imdb_id   ┆ title                ┆ genres              ┆ imdb_rating ┆ sim_embedding ┆ ltr_score │
# │ ---       ┆ ---                  ┆ ---                 ┆ ---         ┆ ---           ┆ ---       │
# │ str       ┆ str                  ┆ str                 ┆ f64         ┆ f64           ┆ f64       │
# ╞═══════════╪══════════════════════╪═════════════════════╪═════════════╪═══════════════╪═══════════╡
# │ tt2024544 ┆ 12 Years a Slave     ┆ Biography,Drama,His ┆ 8.1         ┆ 0.519383      ┆ 15.17054  │
# ...

# %% [markdown]
# # 3. IMDB API

# %%
# ============= FUNCIONES DE VISUALIZACION =============

def show_movie_by_id(movie_id: str):
    """Mostrar informacion de pelicula desde IMDB API."""
    url = f"https://api.imdbapi.dev/titles/{movie_id}"

    response = requests.get(url, headers={"accept": "application/json"})

    if response.status_code != 200:
        display(Markdown(f"Error fetching movie `{movie_id}`"))
        return

    data = response.json()

    title = data.get("primaryTitle", "Unknown title")
    plot = data.get("plot", "No plot available")
    year = data.get("startYear", "N/A")
    rating = data.get("rating", {}).get("aggregateRating", "N/A")
    genres = ", ".join(data.get("genres", []))
    image_url = data.get("primaryImage", {}).get("url")

    display(Markdown(f"### {title} ({year})"))
    display(Markdown(f"**Rating:** {rating} | **Genres:** {genres}"))
    display(Markdown(f"**Plot:** {plot}"))

    if image_url:
        display(Image(url=image_url, width=200))
    
    display(Markdown("---"))


def show_multiple_movies(movie_ids: list[str], max_display: int = 5):
    """Mostrar multiples peliculas en formato compacto."""
    display(Markdown(f"## Top {len(movie_ids)} Resultados"))
    display(Markdown("---"))
    
    for i, movie_id in enumerate(movie_ids[:max_display], 1):
        display(Markdown(f"**#{i}** - ID: `{movie_id}`"))
        show_movie_by_id(movie_id)


def display_results_table(results_df: pl.DataFrame):
    """Mostrar resultados en formato tabla."""
    display(Markdown("## Resultados del Pipeline de Busqueda"))
    
    display_df = results_df.select([
        "imdb_id", "title", "genres", "imdb_rating", "ltr_score"
    ]).with_columns([
        pl.col("ltr_score").round(4),
        pl.col("imdb_rating").round(1),
    ])
    
    # Crear tabla HTML
    html = "<table style='width:100%; border-collapse: collapse;'>"
    html += "<tr style='background-color: #f2f2f2;'>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>#</th>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>IMDB ID</th>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>Title</th>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>Genres</th>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>Rating</th>"
    html += "<th style='padding: 8px; border: 1px solid #ddd;'>LTR Score</th>"
    html += "</tr>"
    
    for i, row in enumerate(display_df.iter_rows(named=True), 1):
        html += f"<tr>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'>{i}</td>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'><code>{row['imdb_id']}</code></td>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'>{row['title']}</td>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'>{row['genres'] or 'N/A'}</td>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'>{row['imdb_rating']}</td>"
        html += f"<td style='padding: 8px; border: 1px solid #ddd;'>{row['ltr_score']}</td>"
        html += f"</tr>"
    
    html += "</table>"
    display(HTML(html))

# %%
# ============= MOSTRAR RESULTADOS =============

# Mostrar tabla de resultados
display_results_table(ranked_results)

# Obtener lista de IDs para uso manual
top_10_ids = ranked_results["imdb_id"].to_list()
print(f"\nTop 10 IMDB IDs para uso manual:")
print(top_10_ids)
# Out:
# ## Resultados del Pipeline de Busqueda
# ...

# %% [markdown]
# # 4. Pipeline Completo

# %%
# ============= PIPELINE COMPLETO DE BUSQUEDA =============

def search_pipeline(
    query: str,
    client: QdrantClient = client,
    collection_name: str = COLLECTION_NAME,
    embedding_model: SentenceTransformer = embedding_model,
    ltr_model = ltr_model,
    movies_df: pl.DataFrame = movies_db,
    top_k_retrieval: int = TOP_K_RETRIEVAL,
    top_k_final: int = TOP_K_FINAL,
    use_hybrid: bool = True,
) -> pl.DataFrame:
    """
    Pipeline completo de busqueda: Retrieval + Re-ranking.
    
    Args:
        query: Texto de busqueda
        use_hybrid: Si True, usa busqueda hibrida (embeddings + BM25)
    
    Returns:
        DataFrame con resultados rankeados
    """
    print(f"Query: '{query}'")
    print("-" * 50)
    
    # Step 1: Retrieval
    if use_hybrid:
        print("Retrieval: Hibrido (Embeddings + BM25)")
        candidates = hybrid_search(
            query=query,
            client=client,
            collection_name=collection_name,
            embedding_model=embedding_model,
            top_k=top_k_retrieval
        )
    else:
        print("Retrieval: Solo Embeddings")
        candidates = semantic_search_only(
            query=query,
            client=client,
            collection_name=collection_name,
            embedding_model=embedding_model,
            top_k=top_k_retrieval
        )
    
    print(f"   Candidatos recuperados: {len(candidates)}")
    
    # Step 2: Re-ranking
    print("Re-ranking con modelo LTR...")
    results = rerank_candidates(
        candidates=candidates,
        query=query,
        movies_df=movies_df,
        embedding_model=embedding_model,
        ltr_model=ltr_model,
        feature_cols=FEATURE_COLS,
        top_k=top_k_final
    )
    
    print(f"   Resultados finales: {len(results)}")
    print("-" * 50)
    
    return results

# %%
# ============= EJECUTAR PIPELINE =============
print("=" * 60)
print("PIPELINE DE BUSQUEDA - DEMO")
print("=" * 60)

results = search_pipeline(QUERY)
display_results_table(results)

# Imprimir IDs para uso manual
print(f"\nTop {TOP_K_FINAL} IMDB IDs:")
for i, imdb_id in enumerate(results["imdb_id"].to_list(), 1):
    title = results.filter(pl.col("imdb_id") == imdb_id)["title"][0]
    print(f"  {i}. {imdb_id} - {title}")
# Out:
# ...
# PIPELINE DE BUSQUEDA - DEMO
# ...
# Query: 'similar to 12 years a slave but more hopeful'
# --------------------------------------------------
# Retrieval: Hibrido (Embeddings + BM25)
#    Candidatos recuperados: 100
# Re-ranking con modelo LTR...
#    Resultados finales: 10
# --------------------------------------------------
# /Users/miguelarquezabdala/repos/dsrp-machine-learning-engineering-4/notebooks/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRanker was fitted with feature names
#   warnings.warn(
# ## Resultados del Pipeline de Busqueda
# ...

# %%
# ============= MOSTRAR MEJOR RESULTADO =============
if not results.is_empty():
    top_movie_id = results["imdb_id"][9]
    print(f"Mejor resultado para: '{QUERY}'")
    print("=" * 50)
    show_movie_by_id(top_movie_id)
# Out:
# Mejor resultado para: 'similar to 12 years a slave but more hopeful'
# ...
# ### Neon Genesis Evangelion: Death & Rebirth (1997)
# **Rating:** 7.2 | **Genres:** Animation, Action, Drama, Sci-Fi
# **Plot:** A recap of the first 24 episodes of Neon Genesis Evangelion, followed by a 30-minute continuation of the plot that would later form the first third of The End of Evangelion.
# <img src="https://m.media-amazon.com/images/M/MV5BMGRiOWQyOTAtZDQ0Ny00NGRiLWIyYTYtZWM1MjNjNzg0ZjE3XkEyXkFqcGc@._V1_.jpg" width="200"/>
# ---

# %% [markdown]
# # 5. Busquedas Interactivas

# %%
# ============= PROBAR OTRAS QUERIES =============
# Cambiar la query y ejecutar esta celda para probar diferentes busquedas

TEST_QUERY = "Similar to the god father"

print("=" * 60)
test_results = search_pipeline(TEST_QUERY)
display_results_table(test_results)

# Lista de IDs para uso manual
print(f"\nIDs para show_movie_by_id():")
print(test_results["imdb_id"].to_list())
# Out:
# ...
# Query: 'Similar to the god father'
# --------------------------------------------------
# Retrieval: Hibrido (Embeddings + BM25)
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/repos/dsrp-machine-learning-engineering-4/notebooks/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/repos/dsrp-machine-learning-engineering-4/notebooks/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# ...

# %%
# ============= MOSTRAR PELICULA MANUAL =============
# Copiar un ID de la lista anterior y pegarlo aqui

MOVIE_ID = "tt25405130"  # Cambiar por el ID deseado
show_movie_by_id(MOVIE_ID)
# Out:
# ### Dada (2023)
# **Rating:** 8.1 | **Genres:** Drama, Family, Romance
# **Plot:** A couple in love, accidentally become teenage parents. Unpleasant situations make them fall apart. Manikandan, left alone with his son, struggles as a single teenage father. Fate owns him, bringing Sindhu back into his life.
# <img src="https://m.media-amazon.com/images/M/MV5BM2NjY2RhNDktMDUwOS00MGMxLWIxYmYtY2UwMmU2YzQzYjg4XkEyXkFqcGc@._V1_.jpg" width="200"/>
# ---
