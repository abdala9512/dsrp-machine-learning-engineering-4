# %% [markdown]
# # Feature Engineering - Pipeline de Datos
# ## DSRP - Curso de Ingenieria de ML
#
# Este notebook se encarga de:
# 1. **Carga de datos**: Combinar IMDB base con datos de OMDB
# 2. **Generacion de embeddings**: Crear representaciones vectoriales de peliculas
# 3. **Feature engineering**: Agregar features derivadas
# 4. **Persistencia**: Guardar dataset procesado
#
# Los datos generados aqui son consumidos por `synthetic_queries.ipynb` para crear el dataset LTR.

# %%
import numpy as np
import polars as pl
from sentence_transformers import SentenceTransformer

# Utilidades compartidas
from ml_utils import (
    load_imdb_database,
    add_derived_features,
    extract_top_genres,
    extract_decades,
    DEFAULT_EMBEDDING_MODEL,
)

# %% [markdown]
# ## 1. Configuracion

# %%
# Rutas de datos
MOVIES_BASE_PATH = "data/movies_base.parquet"
OMDB_PATH = "data/omdb_raw.jsonl"
OUTPUT_DATABASE_PATH = "data/complete_imdb_database.parquet"
EMBEDDINGS_PATH = "data/movie_embs.npy"

# Modelo de embeddings
EMBEDDING_MODEL = DEFAULT_EMBEDDING_MODEL
BATCH_SIZE = 64

# %% [markdown]
# ## 2. Carga y Preparacion de Datos

# %%
# Cargar y combinar datos de IMDB + OMDB
complete_database = load_imdb_database(
    movies_path=MOVIES_BASE_PATH,
    omdb_path=OMDB_PATH
)

print(f"Se cargaron {complete_database.height} peliculas")
print(f"Columnas: {complete_database.columns}")
complete_database.head(3)

# %%
# Guardar base de datos completa (sin features derivadas)
complete_database.write_parquet(OUTPUT_DATABASE_PATH)
print(f"Base de datos guardada en {OUTPUT_DATABASE_PATH}")

# %% [markdown]
# ## 3. Generacion de Embeddings
#
# Creamos representaciones vectoriales de las peliculas usando el titulo y la sinopsis (Plot).
# Estos embeddings se usan para:
# - Busqueda semantica
# - Recuperacion de candidatos para LTR
# - Almacenamiento en Qdrant

# %%
# Cargar modelo de embeddings
model = SentenceTransformer(EMBEDDING_MODEL)
print(f"Modelo cargado: {EMBEDDING_MODEL}")
print(f"Dimension de embeddings: {model.get_sentence_embedding_dimension()}")

# %%
# Crear textos para embedding: titulo + sinopsis
texts = (complete_database["title"] + ". " + complete_database["Plot"].fill_null("")).to_list()

print(f"Generando embeddings para {len(texts)} peliculas...")
embs = model.encode(texts, batch_size=BATCH_SIZE, show_progress_bar=True)
embs = np.asarray(embs, dtype="float32")

print(f"Forma de embeddings: {embs.shape}")

# %%
# Guardar embeddings
np.save(EMBEDDINGS_PATH, embs)
print(f"Embeddings guardados en {EMBEDDINGS_PATH}")

# %% [markdown]
# ## 4. Feature Engineering
#
# Agregamos features derivadas utiles para el modelo de ranking:
# - `imdb_votes_log`: Log de votos (normaliza distribucion)
# - `year_norm`: Año normalizado (z-score)
# - `movie_age`: Edad de la pelicula
# - `plot_length`: Longitud de la sinopsis
# - `genre_action`: Indicador binario de genero Action

# %%
# Agregar features derivadas
complete_database_features = add_derived_features(complete_database)

print(f"Nuevas columnas: {[c for c in complete_database_features.columns if c not in complete_database.columns]}")
complete_database_features.head(3)

# %%
# Estadisticas de las nuevas features
print("Estadisticas de features numericas:")
complete_database_features.select([
    "imdb_rating",
    "imdb_votes_log",
    "year_norm",
    "movie_age",
    "plot_length"
]).describe()

# %% [markdown]
# ## 5. Extraccion de Metadata
#
# Extraemos informacion util para la generacion de queries sinteticas.

# %%
# Extraer generos principales
top_genres = extract_top_genres(complete_database, top_n=15)
print(f"Top 15 generos: {top_genres}")

# %%
# Extraer decadas
decades = extract_decades(complete_database)
print(f"Decadas en el dataset: {decades}")

# %%
# Distribucion de generos
genre_counts = (
    complete_database
    .select(pl.col("genres").str.split(",").alias("genres_list"))
    .explode("genres_list")
    .with_columns(pl.col("genres_list").str.strip_chars().alias("genre"))
    .filter(pl.col("genre").is_not_null() & (pl.col("genre") != ""))
    .group_by("genre")
    .len()
    .sort("len", descending=True)
)

print("Distribucion de generos (top 20):")
genre_counts.head(20)

# %% [markdown]
# ## 6. Resumen
#
# Archivos generados:
# - `data/complete_imdb_database.parquet`: Base de datos completa de peliculas
# - `data/movie_embs.npy`: Embeddings de peliculas (titulo + sinopsis)
#
# Siguiente paso: Ejecutar `synthetic_queries.ipynb` para generar el dataset LTR.

# %%
print("=" * 50)
print("RESUMEN DE FEATURE ENGINEERING")
print("=" * 50)
print(f"Total de peliculas: {complete_database.height}")
print(f"Dimension de embeddings: {embs.shape[1]}")
print(f"Generos unicos: {len(top_genres)}")
print(f"Rango de años: {decades[0]}s - {decades[-1]}s")
print(f"\nArchivos generados:")
print(f"  - {OUTPUT_DATABASE_PATH}")
print(f"  - {EMBEDDINGS_PATH}")
